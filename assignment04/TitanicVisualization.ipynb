# %% [markdown]
# # Titanic Visualization

# %% [markdown]
# ## Imports

# %%
from altair import *

# %%
from seaborn.utils import load_dataset as lds

# %%
df = lds('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who adult_male deck  embark_town alive  alone
# 0    man       True  NaN  Southampton    no  False
# 1  woman      False    C    Cherbourg   yes  False
# 2  woman      False  NaN  Southampton   yes   True
# 3  woman      False    C  Southampton   yes  False
# 4    man       True  NaN  Southampton    no   True

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %% [markdown]
# # Age, sex and class
#
# Create a visualization to answer the following question:
#
# > How do the age, sex and class affect whether the person survived?
#
# Build your visualization using:
#
# * Tick marks
# * X -> age
# * Y -> sex
# * Color -> survived
# * Row -> class

# %%
Chart(df).mark_tick().encode(
    X('age:Q'),
    Y('sex:N'),
    Color('survived:N'),
    Row('class:O')
)
# Out:
# <div class="vega-embed" id="ea8b5f82-fc94-4074-b264-463754bab3dd"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# # Age and fare
#
# Create a visualization to answer the following question:
#
# > Are there interesting patterns in the age, fare space related to a passenger surviving or not?
#
# Build your visualization using:
#
# * Point marks
# * X -> age
# * Y -> fare on a log scale
# * Color -> survived on a scale with green for survived and red for not
# * Row -> sex
# * Size -> class on a scale with Third the smallest and First the largest

# %%
Chart(df).mark_point().encode(
    X('age:Q'),
    Y('fare:Q'),
    Color('survived:N'),
    Row('sex:N'),
    Size('class:O')
)
# Out:
# <div class="vega-embed" id="0fdac3c8-f747-4d2a-8b86-ae0fee185b85"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
Chart(df).mark_point().encode(
    X('age:Q'),
    Y('fare:Q', scale=Scale(type='log')),
    Color('survived:N', scale=Scale(domain=[0, 1], range=['red', '#00ff00'])),
    Row('sex:N'),
    Size('class:O', scale=Scale(domain=['Third', 'Second', 'First']))
)
# Out:
# <div class="vega-embed" id="9bf18ec3-d693-4ee2-9f9c-100fc59610e9"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# # Fare distribution
#
# Create a visualization to answer the following question:
#
# > How does the fare distribution vary with geographic region?
#
# Build your visualization using:
#
# * Bar marks as a histogram
# * X -> binned fare with at most 100 bins
# * Y -> the number of records, with 3 labeled ticks and a title of `N`
# * Row -> embark town, with a custom title of `Town`
# * A custom cell size of height 60 and width 240

# %%
Chart(df).mark_bar().encode(
    X('fare:Q', bin=Bin(maxbins=100)),
    Y('count(*):Q', axis=Axis(ticks=3), title='N'),
    Row('embark_town:N', title='Town'),
).configure_cell(height=60, width=240)
# Out:
# <div class="vega-embed" id="8bd3c6d3-d52f-4b51-a109-6ce3bd304cbf"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>
