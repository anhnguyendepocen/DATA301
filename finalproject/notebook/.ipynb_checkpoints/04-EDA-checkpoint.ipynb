# %% [markdown]
# # Imports
# The only module used for visualization was *Altair*.

# %%
from altair import *
import pandas as pd

# %% [markdown]
# **Transformed Files**

# %%
savedFileDir = '/data/chazalex/transforms/' #file directory from which to load transformed files
savedFileNames = ['spPerceptions.csv', 'faSpPerceptions.csv', 'battery.csv', 'batteryPartIDAvg.csv', 'batteryDateAvg.csv', 
                  'batMergeSpDate.csv']
dfList = [pd.read_csv('/data/chazalex/transforms/'+fileName) for fileName in savedFileNames]

# %% [markdown]
# ---
# # Initial Visualizations

# %%
dfList[0].head()
# Out:
#   participantID  Days felt Happy or content  Days felt Calm or peaceful  \
# 0    sp10-01-02                        20.0                        15.0
# 1    sp10-01-01                         3.0                         3.0
# 2    sp10-01-05                        15.0                        13.0
# 3    sp10-01-03                        25.0                        20.0
# 4    sp10-01-04                        30.0                        28.0
#
#    Days felt Stressed or anxious  Days felt Sad or depressed  \
# 0                           10.0                        10.0
# 1                            3.0                         3.0
# 2                            1.0                         0.0
# 3                           20.0                         8.0
# 4                            2.0                         0.0
#
#    Days felt Angry or frustrated  \
# 0                           10.0
# 1                            3.0
# 2                            1.0
# 3                            3.0
# 4                            0.0
#
#   Student confidence I am generally confident about my abilities.  \
# 0                                              Agree
# 1                                              Agree
# 2                                              Agree
# 3                                              Agree
# 4                                                NaN
#
#   Student confidence I am good at understanding concepts.  \
# 0                                              Agree
# 1                                              Agree
# 2                                     Strongly Agree
# 3                                              Agree
# 4                                                NaN
#
#   Student confidence I am good at solving problems.  \
# 0                                             Agree
# 1                                             Agree
# 2                                             Agree
# 3                                             Agree
# 4                                               NaN
#
#   Student confidence self-rank I am generally more confident about my abilities.  \
# 0                                            Neutral
# 1                                              Agree
# 2                                              Agree
# 3                                            Neutral
# 4                                                NaN
#
#    ...  In the past week I felt Criticized/put down  \
# 0  ...                            Slightly Disagree
# 1  ...                            Strongly Disagree
# 2  ...                                     Disagree
# 3  ...                               Slightly Agree
# 4  ...                            Strongly Disagree
#
#   In the past week I felt Grateful In the past week I felt Happy  \
# 0                          Neutral             Slightly Disagree
# 1                            Agree                Strongly Agree
# 2                            Agree                Strongly Agree
# 3                   Strongly Agree                         Agree
# 4                   Strongly Agree                Strongly Agree
#
#   In the past week I felt Warm/friendly  \
# 0                        Slightly Agree
# 1                        Strongly Agree
# 2                                 Agree
# 3                                 Agree
# 4                        Strongly Agree
#
#   In the past week I felt Guilty/regretful  \
# 0                                 Disagree
# 1                        Strongly Disagree
# 2                                 Disagree
# 3                                 Disagree
# 4                                 Disagree
#
#   In the past week I felt Compassionate    year month   day  hour
# 0                               Neutral  2010.0   6.0  23.0  18.0
# 1                                 Agree  2010.0   6.0   3.0   2.0
# 2                        Slightly Agree  2010.0   5.0  11.0   1.0
# 3                        Slightly Agree  2010.0   5.0  10.0  23.0
# 4                              Disagree  2010.0   5.0  10.0  19.0
#
# [5 rows x 130 columns]

# %%
Chart(dfList[0]).mark_bar().encode(
    X('participantID'),
    Y('Days felt Happy or content')
)
# Out:
# <div class="vega-embed" id="834a9e68-b3b2-4c21-9529-64ff3bcf2a95"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
dfList[3].head()
# Out:
#   participantID      level   plugged
# 0    fa10-01-01  61.053398  0.327800
# 1    fa10-01-02  76.424866  0.309613
# 2    fa10-01-03  74.347873  0.419573
# 3    fa10-01-04  64.749220  0.354972
# 4    fa10-01-05  63.455649  0.262354

# %%
removedOutliers = dfList[3][dfList[3].plugged < 1000]
Chart(removedOutliers).mark_bar().encode(
    X('participantID:N'),
    Y('plugged:Q')
)
# Out:
# <div class="vega-embed" id="27ee32a8-f0bc-446b-9ff7-7d77f4f7dd6a"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ---
# <!--NAVIGATION-->
# < [Tidy Data](https://data301.calpolydatascience.org/user/chazalex/notebooks/finalproj/notebook/03-Tidy.ipynb)
# | [Modeling](https://data301.calpolydatascience.org/user/chazalex/notebooks/finalproj/notebook/05-Modeling.ipynb) >
