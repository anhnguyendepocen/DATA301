# %%
import pandas as pd

# %% [markdown]
# # Gmaps

# %%
import os
import gmaps as gm

# %%
os.environ
# Out:
# environ({'MPLBACKEND': 'module://ipykernel.pylab.backend_inline', 'LC_ALL': 'C', 'TERM': 'xterm-color', 'USER': 'chazalex', 'LANG': 'C', 'JPY_PARENT_PID': '13467', 'PATH': '/opt/conda/bin:/usr/local/sbin:/usr/local/bin:/sbin:/bin:/usr/sbin:/usr/bin', 'CLICOLOR': '1', 'HOME': '/home/chazalex', 'SHELL': '/bin/bash', 'PAGER': 'cat', 'GIT_PAGER': 'cat'})

# %%
gm.configure(api_key='AIzaSyA_ZdzdRhTH82yW3PHORzmHFv3pnDWz61M')

# %%
csv = pd.read_csv('/data/chazalex/Location.csv')

# %%
csv
# Out:
#        participantID                 date  accuracy       x       y
# 0         sp10-01-53  2010-07-12 18:02:44       182  3813.0  3920.0
# 1         sp10-01-53  2010-07-14 06:02:19      1056  1744.0  2314.0
# 2         sp10-01-53  2010-07-16 00:01:49        28   -20.0   -70.0
# 3         sp10-01-53  2010-07-16 14:59:12        60  3876.0  3700.0
# 4         sp10-01-53  2010-07-16 14:59:58        60  3889.0  3708.0
# 5         sp10-01-53  2010-07-17 03:10:17        60     0.0    -8.0
# 6         sp10-01-53  2010-07-17 06:11:02        60     6.0    -7.0
# 7         sp10-01-53  2010-07-17 21:00:04        60    10.0     2.0
# 8         sp10-01-53  2010-07-18 03:07:17        46    -1.0    44.0
# 9         sp10-01-53  2010-07-18 18:00:55        60    -2.0   -11.0
# 10        sp10-01-53  2010-07-18 21:03:12        60     6.0     1.0
# 11        sp10-01-53  2010-07-19 09:07:51        30  4028.0  3912.0
# 12        sp10-01-53  2010-07-19 12:01:03       182  3958.0  3783.0
# ...

# %% [markdown]
# Figure out how to affine transform x, y values based on MIT's location.

# %%
m = gm.Map()
center = gm.heatmap_layer([(42.358524, -71.094640)])
m.add_layer(center)

# %%
m

# %% [markdown]
# # Openpxyl

# %%
import openpyxl as opxl

# %% [markdown]
# ## Load

# %%
wb = opxl.load_workbook(filename='/data/chazalex/DataRelease/SurveyMonthly.xlsx')
# Out:
# /opt/conda/lib/python3.5/site-packages/openpyxl/reader/worksheet.py:310: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
wb1 = opxl.load_workbook(filename='./test.xlsx')

# %%
ts1 = wb1['Sheet1']

# %%
ts1['D1'].value
# Out:
# 0

# %%
qKey = wb['Question Key']

# %%
qKey["A1"]
# Out:
# <Cell 'Question Key'.A1>

# %% [markdown]
# # To Pandas

# %% [markdown]
# ## No headers/indices

# %%
df1 = pd.DataFrame(qKey.values)

# %%
df1.head()
# Out:
#              0              1        2   \
# 0     Key Words       Question  choices
# 1          None   Demographics     None
# 2          Name           Name     None
# 3  Apartment no  Apartment no.     None
# 4           DOB  Date of birth     None
#
#                                                   3       4     5     6   \
# 0                                            surveys  random  None  None
# 1                                               None    None  None  None
# 2  Initial v1, Initial v2, Initial v3, Initial Fa...    None  None  None
# 3  Initial v1, Initial v2, Initial v3, Initial Fa...    None  None  None
# 4  Initial v1, Initial v2, Initial v3, Initial Fa...    None  None  None
#
#      7     8     9   ...     11    12    13    14    15    16    17    18  \
# 0  None  None  None  ...   None  None  None  None  None  None  None  None
# 1  None  None  None  ...   None  None  None  None  None  None  None  None
# ...

# %% [markdown]
# ## Headers/Indicies

# %%
data = qKey.values
cols = next(data)[0:]
data = list(data)
idx = [r[0] for r in data]
#data = (islice(r, 1, None) for r in data)
df2 = pd.DataFrame(data, columns=cols)

# %%
df2.head()
# Out:
#       Key Words       Question choices  \
# 0          None   Demographics    None
# 1          Name           Name    None
# 2  Apartment no  Apartment no.    None
# 3           DOB  Date of birth    None
# 4        Gender         Gender    None
#
#                                              surveys random   NaN   NaN   NaN  \
# 0                                               None   None  None  None  None
# 1  Initial v1, Initial v2, Initial v3, Initial Fa...   None  None  None  None
# 2  Initial v1, Initial v2, Initial v3, Initial Fa...   None  None  None  None
# 3  Initial v1, Initial v2, Initial v3, Initial Fa...   None  None  None  None
# 4  Initial v1, Initial v2, Initial v3, Initial Fa...   None  None  None  None
#
#     NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  \
# 0  None  None  ...   None  None  None  None  None  None  None  None  None
# 1  None  None  ...   None  None  None  None  None  None  None  None  None
# ...

# %%
df2['Question'].head()
# Out:
# NaN              Demographics
# Name                     Name
# Apartment no    Apartment no.
# DOB             Date of birth
# Gender                 Gender
# Name: Question, dtype: object
