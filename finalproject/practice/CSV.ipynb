# %%
import pandas as pd
import requests

# %%
d1 = requests.get('')

# %%
pd.read_csv('lib14p1.csv')
# Out:
#                                             STLA Name  \
# 0   ALASKA DEPARTMENT OF EDUCATION, DIVISION OF LI...
# 1                      ALABAMA PUBLIC LIBRARY SERVICE
# 2                              ARKANSAS STATE LIBRARY
# 3   ARIZONA STATE LIBRARY, ARCHIVES AND PUBLIC REC...
# 4                            CALIFORNIA STATE LIBRARY
# 5                              COLORADO STATE LIBRARY
# 6                           CONNECTICUT STATE LIBRARY
# 7                 DISTRICT OF COLUMBIA PUBLIC LIBRARY
# 8                      DELAWARE DIVISION OF LIBRARIES
# 9        DIVISION OF LIBRARY AND INFORMATION SERVICES
# 10                     GEORGIA PUBLIC LIBRARY SERVICE
# 11                 HAWAII STATE PUBLIC LIBRARY SYSTEM
# 12                              IOWA LIBRARY SERVICES
# 13                     IDAHO COMMISSION FOR LIBRARIES
# 14                             ILLINOIS STATE LIBRARY
# 15                              INDIANA STATE LIBRARY
# ...
